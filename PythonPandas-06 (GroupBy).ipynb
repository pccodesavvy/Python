# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/purnachandra.dasari/Downloads/AIML-Labs-BLR/PythonTutorial-DS/weather_by_cities.csv')
df
# Out:
#        day      city  temperature  windspeed   event
# 0   1/1/17  new york           32          6    Rain
# 1   1/2/17  new york           36          7   Sunny
# 2   1/3/17  new york           28         12    Snow
# 3   1/4/17  new york           33          7   Sunny
# 4   1/1/17    mumbai           90          5   Sunny
# 5   1/2/17    mumbai           85         12     Fog
# 6   1/3/17    mumbai           87         15     Fog
# 7   1/4/17    mumbai           92          5    Rain
# 8   1/1/17     paris           45         20   Sunny
# 9   1/2/17     paris           50         13  Cloudy
# 10  1/3/17     paris           54          8  Cloudy
# 11  1/4/17     paris           42         10  Cloudy

# %%
g=df.groupby('city')
g

# %%
#The moment we execute above group by command it creates groupby dataframes for each as follows
from IPython.display import Image
Image("/Users/purnachandra.dasari/Downloads/AIML-Labs-BLR/PythonTutorial-DS/DataFrameGroupBy.png")

# %%
#TO see all dataframes info write the snippet as follows
for city,city_df in g:
    #print(city)
    print(city_df)
# Out:
#       day    city  temperature  windspeed  event
# 4  1/1/17  mumbai           90          5  Sunny
# 5  1/2/17  mumbai           85         12    Fog
# 6  1/3/17  mumbai           87         15    Fog
# 7  1/4/17  mumbai           92          5   Rain
#       day      city  temperature  windspeed  event
# 0  1/1/17  new york           32          6   Rain
# 1  1/2/17  new york           36          7  Sunny
# 2  1/3/17  new york           28         12   Snow
# 3  1/4/17  new york           33          7  Sunny
#        day   city  temperature  windspeed   event
# 8   1/1/17  paris           45         20   Sunny
# 9   1/2/17  paris           50         13  Cloudy
# 10  1/3/17  paris           54          8  Cloudy
# 11  1/4/17  paris           42         10  Cloudy

# %%
#To get the particular/specifif dataframe
g.get_group('mumbai')
# Out:
#       day    city  temperature  windspeed  event
# 4  1/1/17  mumbai           90          5  Sunny
# 5  1/2/17  mumbai           85         12    Fog
# 6  1/3/17  mumbai           87         15    Fog
# 7  1/4/17  mumbai           92          5   Rain

# %%
#To get maximum temparature in each of the cities
g.max()
# Out:
#              day  temperature  windspeed  event
# city
# mumbai    1/4/17           92         15  Sunny
# new york  1/4/17           36         12  Sunny
# paris     1/4/17           54         20  Sunny

# %%
# The entire above process is called split apply combine, please look at the following.
from IPython.display import Image
Image('/Users/purnachandra.dasari/Downloads/AIML-Labs-BLR/PythonTutorial-DS/SplitApplyNCombine.png')

# %%
g.mean()
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
#To get all analytics, do execute the following command
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
#TO plot the values on graph use the following command
#%matplotlib inline
#g.plot()

# %%
import numpy as np
g['temperature'].agg(np.mean)
# Out:
# city
# mumbai      88.50
# new york    32.25
# paris       47.75
# Name: temperature, dtype: float64

# %%
g.mean()
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
g.size()
# Out:
# city
# mumbai      4
# new york    4
# paris       4
# dtype: int64

# %%
g.sum()
# Out:
#           temperature  windspeed
# city
# mumbai            354         37
# new york          129         32
# paris             191         51

# %%
g.std()
# Out:
#           temperature  windspeed
# city
# mumbai       3.109126   5.057997
# new york     3.304038   2.708013
# paris        5.315073   5.251984
