# %%
# Following Topics are covered in this note

# Creating DataFrame
# Rows and Column operation
# Indexing

# %%
import pandas as pd

# %%
#Creating a dictionary object
weatherData={
    'Date':['1/1/2019','1/2/2019','1/3/2019','1/4/2019'],
    'Temperature':['36','37','38','39'],
    'Windspeed':['1','3','7','9'],
    'Event':['Rain','Sunny','Cloudy','Snow']
}

# %%
# Use below command to transform into Dataframe 
df1=pd.DataFrame(weatherData)
df1[['Event','Temperature']]
# Out:
#     Event Temperature
# 0    Rain          36
# 1   Sunny          37
# 2  Cloudy          38
# 3    Snow          39

# %%
rows, columns = df1.shape
print(rows)
print(columns)
# Out:
# 4
# 4

# %%
df1
# Out:
#        Date Temperature Windspeed   Event
# 0  1/1/2019          36         1    Rain
# 1  1/2/2019          37         3   Sunny
# 2  1/3/2019          38         7  Cloudy
# 3  1/4/2019          39         9    Snow

# %%
df1[1:2][['Windspeed']]
# Out:
#   Windspeed
# 1         3

# %%
# Reading csv using read csv command directly
df2=pd.read_csv("district_wise_rainfall_normal.csv")

# %%
# To get the dimensions(No of Rows & No of Columns) of DataFrame use following command, Output is a tuple
df2.shape
# Out:
# (640, 19)

# %%
# If we wish to store rows and columns do following way.
rows,columns=df2.shape

# %%
rows
# Out:
# 640

# %%
columns
# Out:
# 19

# %%
# If we want to print only initial few rows in data frame use following command
df2.head()
# Out:
#                       STATE/UT       DISTRICT    JAN   FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2  80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  79.5  105.9  216.5
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  JAN+FEB  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3  306.4  447.0  660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4  323.0  738.3  990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
#
#      MAM    JJAS    OND
# 0  540.7  1207.2  892.1
# 1  483.5  1757.2  705.3
# ...

# %%
# If we want to print only last few rows in data frame use following command
df2.tail()
# Out:
#     STATE/UT        DISTRICT   JAN   FEB   MAR    APR    MAY    JUN     JUL  \
# 635   KERALA   THIRUVANANTHA  19.3  21.1  35.5  116.7  216.6  338.7   228.9
# 636   KERALA          IDUKKI  13.4  22.1  43.6  150.4  232.6  651.6   788.9
# 637   KERALA        KASARGOD   2.3   1.0   8.4   46.9  217.6  999.6  1108.5
# 638   KERALA  PATHANAMTHITTA  19.8  45.2  73.9  184.9  294.7  556.9   539.9
# 639   KERALA         WAYANAD   4.8   8.3  17.5   83.3  174.6  698.1  1110.4
#
#        AUG    SEP    OCT    NOV   DEC  ANNUAL  JAN+FEB    MAM    JJAS    OND
# 635  142.0  161.7  268.0  192.0  62.7  1803.2     40.4  368.8   871.3  522.7
# 636  527.3  308.4  343.2  172.9  48.1  3302.5     35.5  426.6  2276.2  564.2
# 637  636.3  263.1  234.9   84.6  18.4  3621.6      3.3  272.9  3007.5  337.9
# 638  352.7  266.2  359.4  213.5  51.3  2958.4     65.0  553.5  1715.7  624.2
# 639  592.9  230.7  213.1   93.6  25.8  3253.1     13.1  275.4  2632.1  332.5

# %%
# If we want to print certain no.of initial rows or last rows use following command

df2.head(10)
df2.tail(10)
# Out:
#     STATE/UT        DISTRICT   JAN   FEB   MAR    APR    MAY    JUN     JUL  \
# 630   KERALA       KOZHIKODE   2.3   3.9  15.1   80.9  256.6  895.8   955.2
# 631   KERALA      MALAPPURAM   1.7   3.9  12.7   86.8  221.3  660.9   792.9
# 632   KERALA        PALAKKAD   2.9   6.5  22.5   98.7  158.7  464.3   595.4
# 633   KERALA          KOLLAM  17.5  33.7  62.6  158.5  248.5  457.7   398.0
# 634   KERALA        THRISSUR   3.4   7.5  17.0   79.2  289.1  707.4   772.9
# 635   KERALA   THIRUVANANTHA  19.3  21.1  35.5  116.7  216.6  338.7   228.9
# 636   KERALA          IDUKKI  13.4  22.1  43.6  150.4  232.6  651.6   788.9
# 637   KERALA        KASARGOD   2.3   1.0   8.4   46.9  217.6  999.6  1108.5
# 638   KERALA  PATHANAMTHITTA  19.8  45.2  73.9  184.9  294.7  556.9   539.9
# 639   KERALA         WAYANAD   4.8   8.3  17.5   83.3  174.6  698.1  1110.4
#
#        AUG    SEP    OCT    NOV   DEC  ANNUAL  JAN+FEB    MAM    JJAS    OND
# ...

# %%
# Let's say if want to print only from row 2 to 10 use below command (It includes row 2 but not row 10)
df2[2:10]
# Out:
#                       STATE/UT       DISTRICT   JAN    FEB    MAR    APR  \
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN  32.7   15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT  42.2   80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG  33.3   79.5  105.9  216.5
# 5            ARUNACHAL PRADESH  SUBANSIRI F.D  28.0   48.3   85.3  101.5
# 6            ARUNACHAL PRADESH          TIRAP  42.2   72.7  141.0  316.9
# 7            ARUNACHAL PRADESH  ANJAW (LOHIT)  42.2   80.8  176.4  358.5
# 8            ARUNACHAL PRADESH   LOWER DIBANG  83.7  153.9  303.5  383.6
# 9            ARUNACHAL PRADESH      CHANGLANG  70.3  170.9  367.9  554.4
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  JAN+FEB  \
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3  306.4  447.0  660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4  323.0  738.3  990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
# ...

# %%
#If want to print everything follow as below
df2[:] 
#(or) 
df2
# Out:
#                         STATE/UT        DISTRICT    JAN    FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3   57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7   26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7   15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2   80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3   79.5  105.9  216.5
# 5              ARUNACHAL PRADESH   SUBANSIRI F.D   28.0   48.3   85.3  101.5
# 6              ARUNACHAL PRADESH           TIRAP   42.2   72.7  141.0  316.9
# 7              ARUNACHAL PRADESH   ANJAW (LOHIT)   42.2   80.8  176.4  358.5
# 8              ARUNACHAL PRADESH    LOWER DIBANG   83.7  153.9  303.5  383.6
# 9              ARUNACHAL PRADESH       CHANGLANG   70.3  170.9  367.9  554.4
# 10             ARUNACHAL PRADESH      PAPUM PARE   33.5   67.8  106.1  226.9
# ...

# %%
# If we wish to print column names use below command
df2.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'JAN+FEB', 'MAM', 'JJAS',
#        'OND'],
#       dtype='object')

# %%
# If we want to print the content of the particular column use following command
df2.DISTRICT 
#(Or)
df2['DISTRICT']
# Out:
# 0             NICOBAR
# 1       SOUTH ANDAMAN
# 2       N & M ANDAMAN
# 3               LOHIT
# 4          EAST SIANG
# 5       SUBANSIRI F.D
# 6               TIRAP
# 7       ANJAW (LOHIT)
# 8        LOWER DIBANG
# 9           CHANGLANG
# 10         PAPUM PARE
# 11      LOW SUBANSIRI
# 12        UPPER SIANG
# 13         WEST SIANG
# 14      DIBANG VALLEY
# 15        WEST KAMENG
# 16        EAST KAMENG
# 17      TAWANG(W KAME
# 18       KURUNG KUMEY
# 19             CACHAR
# 20            DARRANG
# 21           GOALPARA
# 22             KAMRUP
# 23          LAKHIMPUR
# 24       NORTH CACHAR
# 25             NAGAON
# 26          SIVASAGAR
# 27            BARPETA
# 28             DHUBRI
# 29          DIBRUGARH
#             ...
# 610     BANGALORE RUR
# 611           BELLARY
# 612       CHIKMAGALUR
# 613       CHITRADURGA
# 614            KODAGU
# 615            HASSAN
# 616             KOLAR
# 617            MANDYA
# 618            MYSORE
# 619           SHIMOGA
# ...

# %%
type(df2['DISTRICT']) # Columns are in Dataframes are type Pandas Series
# Out:
# pandas.core.series.Series

# %%
# If we want to restrict certain columns or to get only certain columns use below command
df2[['DISTRICT','OCT']]
# Out:
#            DISTRICT    OCT
# 0           NICOBAR  326.0
# 1     SOUTH ANDAMAN  301.2
# 2     N & M ANDAMAN  276.1
# 3             LOHIT  167.1
# 4        EAST SIANG  206.9
# 5     SUBANSIRI F.D   75.9
# 6             TIRAP  218.7
# 7     ANJAW (LOHIT)  167.1
# 8      LOWER DIBANG  167.2
# 9         CHANGLANG  275.0
# 10       PAPUM PARE  214.7
# 11    LOW SUBANSIRI   78.5
# 12      UPPER SIANG  264.9
# 13       WEST SIANG  126.8
# 14    DIBANG VALLEY  167.2
# 15      WEST KAMENG  233.9
# 16      EAST KAMENG  138.2
# 17    TAWANG(W KAME  233.9
# 18     KURUNG KUMEY   92.3
# 19           CACHAR  182.4
# 20          DARRANG   95.4
# 21         GOALPARA  157.7
# 22           KAMRUP  106.6
# 23        LAKHIMPUR  140.3
# 24     NORTH CACHAR  196.4
# 25           NAGAON  120.0
# 26        SIVASAGAR   96.3
# 27          BARPETA  142.1
# 28           DHUBRI  155.1
# 29        DIBRUGARH  136.9
# ..              ...    ...
# 610   BANGALORE RUR  171.8
# 611         BELLARY  116.3
# ...

# %%
#If we want to find the maximum & Minimum values in any column data use following command
df2['OCT'].max()
df2['OCT'].min()
# Out:
# 3.1

# %%
#If we want get statistical Data use following command
df2.describe()
# Out:
#               JAN         FEB         MAR         APR         MAY  \
# count  640.000000  640.000000  640.000000  640.000000  640.000000
# mean    18.351250   20.994219   30.063281   45.537969   81.394219
# std     21.099075   27.750169   45.480904   71.612125  111.991086
# min      0.000000    0.000000    0.000000    0.000000    0.900000
# 25%      6.875000    7.000000    7.000000    5.000000   12.100000
# 50%     13.300000   12.300000   12.700000   15.050000   33.850000
# 75%     19.125000   24.100000   33.275000   48.075000   91.825000
# max    144.500000  229.600000  367.900000  554.400000  733.700000
#
#                JUN          JUL          AUG         SEP         OCT  \
# count   640.000000   640.000000   640.000000  640.000000  640.000000
# mean    195.797656   326.093594   291.267344  194.658281   90.342188
# std     196.638268   221.532589   152.738890   99.900836   75.002933
# min       3.800000    11.600000    14.100000    8.600000    3.100000
# ...

# %%
df2
# Out:
#                         STATE/UT        DISTRICT    JAN    FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3   57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7   26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7   15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2   80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3   79.5  105.9  216.5
# 5              ARUNACHAL PRADESH   SUBANSIRI F.D   28.0   48.3   85.3  101.5
# 6              ARUNACHAL PRADESH           TIRAP   42.2   72.7  141.0  316.9
# 7              ARUNACHAL PRADESH   ANJAW (LOHIT)   42.2   80.8  176.4  358.5
# 8              ARUNACHAL PRADESH    LOWER DIBANG   83.7  153.9  303.5  383.6
# 9              ARUNACHAL PRADESH       CHANGLANG   70.3  170.9  367.9  554.4
# 10             ARUNACHAL PRADESH      PAPUM PARE   33.5   67.8  106.1  226.9
# ...

# %%
# If we want get data in dataframe using condition (This is similar to SQL Query)
df2[df2.OCT>=500]
# Out:
#      STATE/UT       DISTRICT   JAN   FEB    MAR    APR    MAY     JUN     JUL  \
# 47  MEGHALAYA  JAINTIA HILLS  33.8  44.1  115.1  282.3  598.8  1316.1  1591.3
#
#       AUG    SEP    OCT    NOV  DEC  ANNUAL  JAN+FEB    MAM    JJAS    OND
# 47  933.8  826.3  517.7  110.9  9.7  6379.9     77.9  996.2  4667.5  638.3

# %%
# If we want to get the complet row of a max value in OCT using condition as follows
df2[df2.OCT==df2.OCT.max()]
#(OR)
df2[df2.OCT==df2['OCT'].max()] # This we'll prefer incase if columns are having any spaces
# Out:
#      STATE/UT       DISTRICT   JAN   FEB    MAR    APR    MAY     JUN     JUL  \
# 47  MEGHALAYA  JAINTIA HILLS  33.8  44.1  115.1  282.3  598.8  1316.1  1591.3
#
#       AUG    SEP    OCT    NOV  DEC  ANNUAL  JAN+FEB    MAM    JJAS    OND
# 47  933.8  826.3  517.7  110.9  9.7  6379.9     77.9  996.2  4667.5  638.3

# %%
#If we want to know the state where weather where max rainfall in Oct month
df2[['STATE/UT','DISTRICT']][df2.OCT==df2['OCT'].max()]
# Out:
#      STATE/UT       DISTRICT
# 47  MEGHALAYA  JAINTIA HILLS

# %%
df2.reset_index(inplace=True)

# %%
#If we want to know index of DataFrame
df2.index
# Out:
# RangeIndex(start=0, stop=640, step=1)

# %%
#If we want to set any particular column as index do as below
df2.set_index('STATE/UT', inplace=True)

# %%
df2.loc['KERALA']
# Out:
#           index        DISTRICT   JAN   FEB   MAR    APR    MAY    JUN  \
# STATE/UT
# KERALA      626       ALAPPUZHA  17.5  27.9  45.1  134.0  298.7  593.0
# KERALA      627          CANNUR   2.5   2.0   7.6   57.9  235.0  852.4
# KERALA      628       ERNAKULAM  13.2  18.8  31.2  112.0  300.4  696.4
# KERALA      629        KOTTAYAM  13.0  24.9  42.3  136.1  281.8  649.1
# KERALA      630       KOZHIKODE   2.3   3.9  15.1   80.9  256.6  895.8
# KERALA      631      MALAPPURAM   1.7   3.9  12.7   86.8  221.3  660.9
# KERALA      632        PALAKKAD   2.9   6.5  22.5   98.7  158.7  464.3
# KERALA      633          KOLLAM  17.5  33.7  62.6  158.5  248.5  457.7
# KERALA      634        THRISSUR   3.4   7.5  17.0   79.2  289.1  707.4
# KERALA      635   THIRUVANANTHA  19.3  21.1  35.5  116.7  216.6  338.7
# KERALA      636          IDUKKI  13.4  22.1  43.6  150.4  232.6  651.6
# KERALA      637        KASARGOD   2.3   1.0   8.4   46.9  217.6  999.6
# ...
